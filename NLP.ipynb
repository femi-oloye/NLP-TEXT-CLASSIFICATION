# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d5df0069828e> in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     197       raise ValueError('Mountpoint must not be a symlink')
#     198     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/
# Out:
#  Alzhiemer_data.csv				     'Portfolio (1).gsite'
#  bert_finetuned					      Portfolio.gsite
#  CALLBACKS.gsheet				      sharonData.gsheet
#  cleaned_fifa21data.csv				     'telemarketers data.csv'
# 'Colab Notebooks'				     'Untitled spreadsheet (1).gsheet'
# 'Copy of Example of Project Charter.gdoc'	     'Untitled spreadsheet (2).gsheet'
# 'Copy of Project Design Doc TEMPLATE - [GDOC].gdoc'  'Untitled spreadsheet (3).gsheet'
#  HOWFAH.gsheet					     'Untitled spreadsheet (4).gsheet'
# 'IMDB Dataset.csv'				     'Untitled spreadsheet.gform'
#  NLP.ipynb					     'Untitled spreadsheet.gsheet'

# %%
import os

dataset_path = "/content/drive/MyDrive"
os.listdir(dataset_path)
# Out:
# ['IMDB Dataset.csv',
#  'Copy of Project Design Doc TEMPLATE - [GDOC].gdoc',
#  'Copy of Example of Project Charter.gdoc',
#  'Portfolio (1).gsite',
#  'Portfolio.gsite',
#  'telemarketers data.csv',
#  'Untitled spreadsheet (4).gsheet',
#  'Untitled spreadsheet.gform',
#  'Untitled spreadsheet (3).gsheet',
#  'Untitled spreadsheet (2).gsheet',
#  'Untitled spreadsheet (1).gsheet',
#  'CALLBACKS.gsheet',
#  'cleaned_fifa21data.csv',
#  'Untitled spreadsheet.gsheet',
#  'Alzhiemer_data.csv',
#  'sharonData.gsheet',
#  'Colab Notebooks',
#  'HOWFAH.gsheet',
#  'bert_finetuned',
#  'NLP.ipynb']

# %%
# !ls /content/drive/MyDrive/
# Out:
# bert_finetuned

# %%
# !pip install transformers datasets torch torchvision torchaudio
# Out:
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/nvidia-cusparse-cu12/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 97.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("imdb")  # This loads the IMDB dataset

# %%
from transformers import BertTokenizerFast

tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

tokenized_datasets = dataset.map(tokenize_function, batched=True)
# Out:
# ...
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-51d60d4b2aec> in <cell line: 0>()
#       2     return tokenizer(examples["text"], padding="max_length", truncation=True)
#       3
# ----> 4 tokenized_datasets = dataset.map(tokenize_function, batched=True)
#
# /usr/local/lib/python3.11/dist-packages/datasets/dataset_dict.py in map(self, function, with_indices, with_rank, with_split, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     939                 function = bind(function, split)
#     940
# --> 941             dataset_dict[split] = dataset.map(
#     942                 function=function,
#     943                 with_indices=with_indices,
#
# ...

# %%
from datasets import DatasetDict

# Assuming 'tokenized_test_dataset' is your processed dataset
tokenized_datasets.save_to_disk("/content/drive/MyDrive/tokenized_test_dataset")

# %%
small_train_dataset = tokenized_datasets["train"].select(range(5000))
small_test_dataset = tokenized_datasets["test"].select(range(1000))

# %%
from transformers import BertForSequenceClassification

model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=8,  # Small batch size
    per_device_eval_batch_size=8,
    num_train_epochs=2,  # Only 2 epochs to reduce time
    logging_dir="./logs",
    report_to="none",
    logging_steps=10,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1611: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
import wandb
wandb.login(anonymous="must")
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: anony-moose-329663656166560913 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !pip install wandb

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train_dataset,
    eval_dataset=small_test_dataset,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='1250' max='1250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1250/1250 17:22, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000014</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000000</td>
#       <td>0.000009</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1250, training_loss=0.001102709169400623, metrics={'train_runtime': 1044.8322, 'train_samples_per_second': 9.571, 'train_steps_per_second': 1.196, 'total_flos': 2631110553600000.0, 'train_loss': 0.001102709169400623, 'epoch': 2.0})

# %%
model.save_pretrained("/content/drive/MyDrive/bert_finetuned")
tokenizer.save_pretrained("/content/drive/MyDrive/bert_finetuned")
# Out:
# ('/content/drive/MyDrive/bert_finetuned/tokenizer_config.json',
#  '/content/drive/MyDrive/bert_finetuned/special_tokens_map.json',
#  '/content/drive/MyDrive/bert_finetuned/vocab.txt',
#  '/content/drive/MyDrive/bert_finetuned/added_tokens.json',
#  '/content/drive/MyDrive/bert_finetuned/tokenizer.json')

# %%
import torch
from transformers import BertForSequenceClassification, BertTokenizer

model_path = "/content/drive/MyDrive/bert_finetuned"

# Load the fine-tuned model
model = BertForSequenceClassification.from_pretrained(model_path)

# Load the tokenizer
tokenizer = BertTokenizer.from_pretrained(model_path)

# Load test dataset
test_encodings = torch.load("/content/tokenized_test_dataset.pt")  # Adjust path if needed
test_labels = torch.tensor(test_encodings['labels'])  # Extract labels

# Create DataLoader
from torch.utils.data import DataLoader, TensorDataset

test_dataset = TensorDataset(test_encodings['input_ids'], test_encodings['attention_mask'], test_labels)
test_loader = DataLoader(test_dataset, batch_size=16)

# Define evaluation function
from torch.nn.functional import softmax

def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in test_loader:
            inputs = {'input_ids': batch[0], 'attention_mask': batch[1]}
            labels = batch[2]
            outputs = model(**inputs)
            probs = softmax(outputs.logits, dim=1)
            preds = torch.argmax(probs, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(preds.tolist())
            all_labels.extend(labels.tolist())

    accuracy = correct / total
    print(f"Model Accuracy on Test Set: {accuracy:.4f}")

evaluate(model, test_loader)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-7c9391d4ee49> in <cell line: 0>()
#      11
#      12 # Load test dataset
# ---> 13 test_encodings = torch.load("/content/tokenized_test_dataset.pt")  # Adjust path if needed
#      14 test_labels = torch.tensor(test_encodings['labels'])  # Extract labels
#      15
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1423         pickle_load_args["encoding"] = "utf-8"
#    1424
# -> 1425     with _open_file_like(f, "rb") as opened_file:
#    1426         if _is_zipfile(opened_file):
#    1427             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
# ...

# %%
import torch
from datasets import load_dataset, DatasetDict
from transformers import BertForSequenceClassification, BertTokenizer
from transformers import TrainingArguments, Trainer
from torch.utils.data import DataLoader, TensorDataset
from torch.nn.functional import softmax

# Load dataset
dataset = load_dataset("imdb")

# Load tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Tokenization function
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)

# Tokenize dataset
tokenized_datasets = dataset.map(tokenize_function, batched=True)

# Save tokenized test dataset correctly using Hugging Face save_to_disk()
test_encodings = tokenized_datasets["test"].select(range(1000))
test_encodings.save_to_disk("/content/drive/MyDrive/tokenized_test_dataset")  # ✅ Correct way to save dataset

# Use small subsets for training & testing
small_train_dataset = tokenized_datasets["train"].select(range(5000))
small_test_dataset = tokenized_datasets["test"].select(range(1000))

# Load BERT model for binary classification (positive vs negative)
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=2,
    logging_dir="./logs",
    report_to="none",
    logging_steps=10,
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=small_train_dataset,
    eval_dataset=small_test_dataset,
)

# Train the model
trainer.train()

# Save model and tokenizer
model_path = "/content/drive/MyDrive/bert_finetuned"
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)

# ----------------------- Loading Model for Evaluation -----------------------

# Load trained model
model = BertForSequenceClassification.from_pretrained(model_path)

# Load tokenizer
tokenizer = BertTokenizer.from_pretrained(model_path)

from datasets import load_from_disk
test_encodings = load_from_disk("/content/drive/MyDrive/tokenized_test_dataset")


# Convert tokenized test dataset to tensor format
test_labels = torch.tensor(test_encodings["label"])
test_dataset = TensorDataset(
    torch.tensor(test_encodings["input_ids"]),
    torch.tensor(test_encodings["attention_mask"]),
    test_labels,
)

# Create DataLoader
test_loader = DataLoader(test_dataset, batch_size=16)

# Evaluation function
def evaluate(model, test_loader):
    model.eval()
    correct, total = 0, 0
    all_preds, all_labels = [], []

    with torch.no_grad():
        for batch in test_loader:
            inputs = {"input_ids": batch[0], "attention_mask": batch[1]}
            labels = batch[2]
            outputs = model(**inputs)
            probs = softmax(outputs.logits, dim=1)
            preds = torch.argmax(probs, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

            all_preds.extend(preds.tolist())
            all_labels.extend(labels.tolist())

    accuracy = correct / total
    print(f"Model Accuracy on Test Set: {accuracy:.4f}")

# Run evaluation
evaluate(model, test_loader)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git clone https://github.com/femi-oloye/NLP-TEXT-CLASSIFICATION.git
# %cd NLP-TEXT-CLASSIFICATION
# Out:
# Cloning into 'NLP-TEXT-CLASSIFICATION'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
# /content/NLP-TEXT-CLASSIFICATION

# %%
# !cp -r /content/bert_finetuned .  # Copy saved model
# !cp /content/drive/MyDrive/tokenized_test_dataset .  # Copy dataset
# !cp /content/drive/MyDrive/NLP.ipynb .  # If you wrote an evaluation script
# Out:
# cp: cannot stat '/content/bert_finetuned': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/tokenized_test_dataset': No such file or directory
# cp: cannot stat '/content/drive/MyDrive/NLP.ipynb': No such file or directory

# %%
# !ls /content/
# !ls /content/drive/MyDrive/
# Out:
# NLP-TEXT-CLASSIFICATION  sample_data
# ls: cannot access '/content/drive/MyDrive/': No such file or directory
